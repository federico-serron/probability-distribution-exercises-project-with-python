# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(3, size = 4, prob = 0.8) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 4, 2, ..., 0, 3, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
#Code here# Probability functions, density and distribution

def dnormal(x,mean=0,sd=1):
    """
    Calculates the point estimate of the normal distribution
    """
    from scipy.stats import norm
    result=norm.pdf(x=x,loc=mean,scale=sd)
    return result

def pnormal(x,mean=0,sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import norm
    result=norm.cdf(x=x,loc=mean,scale=sd)
    return result

def qnormal(p,mean=0,sd=1):
    """
    Calculates the quantile function from the normal distribution
    """
    from scipy.stats import norm
    result=norm.ppf(q=p,loc=mean,scale=sd)
    return result

def rnormal(mean=0, sd=1, size=10):
    """
    Generates random variables from the normal distribution
    """
    from scipy.stats import norm
    result=norm.rvs(loc=0, scale=1, size=1, random_state=None)
    return result

# %%
# Setting up random variable and their respective mean and sd
X = np.arange(1, 10, 0.1)
mean = np.mean(X)
sd = np.std(X)

# Saving the results in variables to be able to make some graphs
pdf =dnormal(X, mean, sd)
cdf = pnormal(X, mean, sd)
ppf = qnormal(0.5, mean, sd)
rvs = rnormal(mean, sd, 10)

# Making the graphs
figure, axis = plt.subplots(1,2)

# For PDF
axis[0].plot(X, pdf)
axis[0].set_title("Normal Density Distribution")

# For PDF
axis[1].plot(X, cdf)
axis[1].set_title("Cumulative normal Distribution")
# Out:
# Text(0.5, 1.0, 'Cumulative normal Distribution')

# %%
#Code here# Probability functions, density and distribution

def duniform(x,mean=0,sd=1):
    """
    Calculates the point estimate of the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.pdf(x=x,loc=mean,scale=sd)
    return result

def puniform(x,mean=0,sd=1):
    """
    Calculates the cumulative of the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.cdf(x=x,loc=mean,scale=sd)
    return result

def quniform(p,mean=0,sd=1):
    """
    Calculates the quantile function from the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.ppf(q=p,loc=mean,scale=sd)
    return result

def runiform(mean=0, sd=1, size=10):
    """
    Generates random variables from the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.rvs(loc=0, scale=1, size=1, random_state=None)
    return result

# %%
# Setting up random variable and their respective mean and sd
X = np.linspace(-10, 10, 100)
mean = np.mean(X)
sd = np.std(X)

# Saving the results in variables to be able to make some graphs
pdf = duniform(X, mean, sd)
cdf = puniform(X, mean, sd)

# Making the graphs
figure, axis = plt.subplots(1,2)

# For PDF
axis[0].plot(X, pdf)
axis[0].set_title("Uniform density Distribution")

# For PDF
axis[1].plot(X, cdf)
axis[1].set_title("Cumulative uniform Distribution")
# Out:
# Text(0.5, 1.0, 'Cumulative uniform Distribution')
